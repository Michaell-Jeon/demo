# %%
# %attachments
# Out:
# Training Cluster    ML Engine
# ------------------  -----------
# trainingdemo1       python

# %%
# %%trainingdemo1
# print('test')
# Out:
# History URL: http://kdss-bcjbk-0.kdhs-w45gh.demo1.svc.cluster.local:10001/history/1

# %%
# %logs --url http://kdss-zwxh5-0.kdhs-mqq7s.products.svc.cluster.local:10001/history/5
# Out:
# Job Status: Finished
# test

# %%
# %%trainingdemo1
# import tensorflow as tf
# import keras
# from keras.models import Model, save_model, load_model
# from sklearn.model_selection import train_test_split
# import pandas as pd
# import numpy as np
#
#
#
# load_file  = "/bd-fs-mnt/project_repo/data/iris.csv"
# save_model = "/bd-fs-mnt/project_repo/models/iris/irisModel.h5"
#
# iris_data = pd.read_csv(load_file,encoding="utf-8")
# y_labels = iris_data.loc[:, "species"]
# x_data = iris_data.loc[:,["sepalLength","sepalWidth","petalLength","petalWidth"]]
#
# labels = {'Setosa': [1,0,0], 'Versicolor' : [0,1,0], 'Virginica' : [0,0,1] }
# y_nums = np.array(list(map(lambda v : labels[v], y_labels)))
# x_data = np.array(x_data)
#
# x_train, x_test, y_train, y_test = train_test_split(x_data, y_nums, train_size=0.8)
#
# Dense = keras.layers.Dense
# model = keras.models.Sequential()
# model.add(Dense(10,activation='relu', input_shape=(4,)))
# model.add(Dense(3,activation='softmax'))
#
# model.compile( loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
# model.fit(x_train, y_train, batch_size=20, epochs=300)
#
# score = model.evaluate(x_test, y_test, verbose=1)
# print('Accuracy = ', score[1], ' loss = ',score[0])
#
# print("Saving model")
# model.save(save_model)
#
# # Prepare TF Serving
# #print("Preparing for TF Serving")
# #MODEL_VERSION = 1
# #tf.keras.backend.set_learning_phase(0)
# #model = tf.keras.models.load_model(save_model)
# #export_path = '/bd-fs-mnt/project_repo/models/iris/' + str(MODEL_VERSION)
# #tf.keras.models.save_model(model, export_path)
#
# # Summarize model.
# model.summary()
# print("Done")
# Out:
# History URL: http://kdss-xtq46-0.kdhs-w45gh.demo1.svc.cluster.local:10001/history/2

# %%
# %logs --url http://kdss-xtq46-0.kdhs-w45gh.demo1.svc.cluster.local:10001/history/2
# Out:
# Job Status: Finished
# Epoch 1/300
#
# ...
# 120/120 [==============================] - 0s 1ms/step - loss: 3.1674 - accuracy: 0.3583
# Epoch 2/300
#
# ...
# 120/120 [==============================] - 0s 47us/step - loss: 2.9730 - accuracy: 0.3583
# Epoch 3/300
#
# ...
# 120/120 [==============================] - 0s 45us/step - loss: 2.7794 - accuracy: 0.3583
# Epoch 4/300
#
# ...
# 120/120 [==============================] - 0s 47us/step - loss: 2.6176 - accuracy: 0.3583
# Epoch 5/300
#
# ...
# 120/120 [==============================] - 0s 48us/step - loss: 2.4805 - accuracy: 0.3583
# Epoch 6/300
#
# ...
# 120/120 [==============================] - 0s 49us/step - loss: 2.3577 - accuracy: 0.3583
# Epoch 7/300
#
# ...
# 120/120 [==============================] - 0s 48us/step - loss: 2.2511 - accuracy: 0.3750
# Epoch 8/300
#
# ...
# 120/120 [==============================] - 0s 50us/step - loss: 2.1510 - accuracy: 0.4333
# Epoch 9/300
#
# ...
# 120/120 [==============================] - 0s 50us/step - loss: 2.0763 - accuracy: 0.5333
# ...
